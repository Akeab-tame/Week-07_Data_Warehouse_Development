# %%
import pandas as pd
import logging

# %%
# %cd /Telegram_Scraper/
# Out:
# [WinError 2] The system cannot find the file specified: '/Telegram_Scraper/'
# c:\Users\Hello\Desktop\Html Tutorial\Document\KAIM Courses\Week-07_Data_Warehouse_Development\notebooks
# c:\Users\Hello\Desktop\Html Tutorial\Document\KAIM Courses\Week-07_Data_Warehouse_Development\venv\Lib\site-packages\IPython\core\magics\osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})

# %%
#Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Load the CheMed CSV file
logging.info('Loading the first CSV file...')
df1 = pd.read_csv('../Telegram_Scraper/CheMed123_data.csv')

# Load the DoctorsET CSV file
logging.info('Loading the second CSV file...')
df2 = pd.read_csv('../Telegram_Scraper/DoctorsET_data.csv')

# Load the EAHCI CSV file
logging.info('Loading the second CSV file...')
df3 = pd.read_csv('../Telegram_Scraper/EAHCI_data.csv')

# Load the LOBELIA CSV file
logging.info('Loading the second CSV file...')
df4 = pd.read_csv('../Telegram_Scraper/lobelia4cosmetics_data.csv')

# Load the LOBELIA CSV file
logging.info('Loading the second CSV file...')
df5 = pd.read_csv('../Telegram_Scraper/yetenaweg_data.csv')
# Out:
# 2024-10-12 17:48:31,115 - INFO - Loading the first CSV file...
# 2024-10-12 17:48:31,144 - INFO - Loading the second CSV file...
# 2024-10-12 17:48:31,205 - INFO - Loading the second CSV file...
# 2024-10-12 17:48:31,276 - INFO - Loading the second CSV file...
# 2024-10-12 17:48:31,364 - INFO - Loading the second CSV file...

# %%
# Combine the two DataFrames
logging.info('Combining the all DataFrames...')
df = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)
# Out:
# 2024-10-12 17:48:31,411 - INFO - Combining the all DataFrames...

# %%
df.sample(10)
# Out:
#                                           Channel Title    Channel Username  \
# 2358                     Lobelia pharmacy and cosmetics  @lobelia4cosmetics
# 612                                    Doctors Ethiopia          @DoctorsET
# 14                                               CheMed          @CheMed123
# 3007                                   የጤና ወግ - የጤና መረጃ          @yetenaweg
# 32                                               CheMed          @CheMed123
# 70                                               CheMed          @CheMed123
# 2824                     Lobelia pharmacy and cosmetics  @lobelia4cosmetics
# 2723                     Lobelia pharmacy and cosmetics  @lobelia4cosmetics
# 727                                    Doctors Ethiopia          @DoctorsET
# 1008  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...              @EAHCI
#
#          ID                                            Message  \
# 2358  11913  GLUCOSAMINE 1000MG/100MG 90 CAPSULES \nPrice 5...
# ...

# %% [markdown]
# # Data Overview and Summary

# %%
def summarize_data(df):
    # Basic Information
    def basic_info(df):
        print(df.info())
        print(df.describe(include='all'))
        print(df.isnull().sum())

    # Specific Summarizations
    def specific_summarizations(df):
        num_records = df.shape[0]
        num_unique_values = df.nunique()

        print(f'Number of records: {num_records}')
        print('Number of unique values per column:')
        print(num_unique_values)

        for column in df.columns:
            if df[column].dtype == 'object':
                print(f'\nTop 5 most frequent values in column "{column}":')
                print(df[column].value_counts().head())
            elif df[column].dtype in ['int64', 'float64']:
                total = df[column].sum()
                mean = df[column].mean()
                print(f'\nTotal of column "{column}": {total}')
                print(f'Mean of column "{column}": {mean:.2f}')

                if pd.to_datetime(df[column], errors='coerce').notnull().all():
                    df[column] = pd.to_datetime(df[column])
                    messages_per_period = df[column].dt.to_period('M').value_counts().sort_index()
                    print(f'\nNumber of records per month for column "{column}":')
                    print(messages_per_period)

        numeric_columns = df.select_dtypes(include=['number']).columns
        if not numeric_columns.empty:
            top_messages = df.nlargest(5, numeric_columns[0])
            print('\nTop 5 records by the first numerical column:')
            print(top_messages)

        else:
            print('\nNo numerical columns to display top records.')


    # Calling functions
    print("Basic Information:")
    basic_info(df)
    print("\nSpecific Summarizations:")
    specific_summarizations(df)

# %%
summarize_data(df)
# Out:
# Basic Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3015 entries, 0 to 3014
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel Title     3015 non-null   object
#  1   Channel Username  3015 non-null   object
#  2   ID                3015 non-null   int64
#  3   Message           2487 non-null   object
#  4   Date              3015 non-null   object
#  5   Media Path        2653 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 141.5+ KB
# None
#                                             Channel Title Channel Username  \
# count                                                3015             3015
# unique                                                  5                5
# top     ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI
# freq                                                 1000             1000
# ...

# %% [markdown]
# # Remove duplicates

# %%
logging.info('Removing duplicates...')
df = df.drop_duplicates()
# Out:
# 2024-10-12 17:48:31,667 - INFO - Removing duplicates...

# %% [markdown]
# # Handle missing values

# %%
# Drop a single column 'title'
df = df.dropna()
df.sample(10)
# Out:
#                                           Channel Title    Channel Username  \
# 1636  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...              @EAHCI
# 2281                     Lobelia pharmacy and cosmetics  @lobelia4cosmetics
# 1989                     Lobelia pharmacy and cosmetics  @lobelia4cosmetics
# 1913                     Lobelia pharmacy and cosmetics  @lobelia4cosmetics
# 276                                    Doctors Ethiopia          @DoctorsET
# 2725                     Lobelia pharmacy and cosmetics  @lobelia4cosmetics
# 2131                     Lobelia pharmacy and cosmetics  @lobelia4cosmetics
# 2119                     Lobelia pharmacy and cosmetics  @lobelia4cosmetics
# 1292  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...              @EAHCI
# 2947                                   የጤና ወግ - የጤና መረጃ          @yetenaweg
#
#                                 ID  \
# 1636 1970-01-01 00:00:00.000001551
# 2281 1970-01-01 00:00:00.000011993
# ...

# %%
logging.info('Handling missing values...')
df = df.fillna('')
# Out:
# 2024-10-12 17:48:31,774 - INFO - Handling missing values...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2312 entries, 0 to 3014
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel Title     2312 non-null   object
#  1   Channel Username  2312 non-null   object
#  2   ID                2312 non-null   datetime64[ns]
#  3   Message           2312 non-null   object
#  4   Date              2312 non-null   object
#  5   Media Path        2312 non-null   object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 126.4+ KB

# %%
df.isnull().sum()
# Out:
# Channel Title       0
# Channel Username    0
# ID                  0
# Message             0
# Date                0
# Media Path          0
# dtype: int64

# %% [markdown]
# # Standardize formats

# %%
logging.info('Standardizing formats...')
df['Date'] = pd.to_datetime(df['Date'], errors ='coerce')
df['Message'] = df['Message'].str.strip()
# df['img'] = df['img'].str.strip()
# Out:
# 2024-10-12 17:48:31,861 - INFO - Standardizing formats...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2312 entries, 0 to 3014
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel Title     2312 non-null   object
#  1   Channel Username  2312 non-null   object
#  2   ID                2312 non-null   datetime64[ns]
#  3   Message           2312 non-null   object
#  4   Date              2312 non-null   datetime64[ns, UTC]
#  5   Media Path        2312 non-null   object
# dtypes: datetime64[ns, UTC](1), datetime64[ns](1), object(4)
# memory usage: 126.4+ KB

# %% [markdown]
# # Data validation

# %%
logging.info('Performing data validation...')
assert df['Date'].dt.tz is not None, "Date column should have timezone information"
# Out:
# 2024-10-12 17:48:31,939 - INFO - Performing data validation...

# %%
# Display the cleaned DataFrame
logging.info('Displaying the cleaned DataFrame:')
df.head()
# Out:
# 2024-10-12 17:48:31,959 - INFO - Displaying the cleaned DataFrame:
#   Channel Title Channel Username                            ID  \
# 0        CheMed       @CheMed123 1970-01-01 00:00:00.000000097
# 1        CheMed       @CheMed123 1970-01-01 00:00:00.000000096
# 2        CheMed       @CheMed123 1970-01-01 00:00:00.000000095
# 3        CheMed       @CheMed123 1970-01-01 00:00:00.000000094
# 4        CheMed       @CheMed123 1970-01-01 00:00:00.000000093
#
#                                              Message  \
# 0  ⚠️Notice!\nDear esteemed customers,\nDue to fo...
# 1  Mela-One በውስጡ ሆርሞን ያለው ድንገተኛ ወሊድ መቆጣጠርያ ሲሆን ያለ...
# 2  አዚትሮማይሲን በሃኪም መድሃኒት ማዘዣ ከሚታዘዙ አንቲባዮቲኮች አንዱ ሲሆን...
# 3  Che-Med Trivia #3\n\nምግብና መጠጦች አንዳንድ መድሃኒቶች በደ...
# 4  Che-Med Trivia #2\n\nእንደ Ciprofloxacin, Doxycy...
#
#                        Date                Media Path
# 0 2023-02-10 12:23:06+00:00  photos\@CheMed123_97.jpg
# 1 2023-02-02 08:58:52+00:00  photos\@CheMed123_96.jpg
# ...

# %%
df.to_csv('cleaned_data.csv')

# %% [markdown]
# # Storing Cleaned Data

# %%
import psycopg2
from sqlalchemy import create_engine

# %%
DATABASE_URL = "postgresql+psycopg2://postgres:Akeab@localhost:5432/medical_db"

# %%
from sqlalchemy import create_engine, Column, Integer, String, Float
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
import psycopg2

engine = create_engine(DATABASE_URL)

# Base class for declaring models
Base = declarative_base()

# Create a session
Session = sessionmaker(bind=engine)
session = Session()
# Out:
# C:\Users\Hello\AppData\Local\Temp\ipykernel_14160\1304629478.py:9: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %%
from sqlalchemy import create_engine, Column, Integer, String, Date
from sqlalchemy.ext.declarative import declarative_base

Base = declarative_base()
# Out:
# C:\Users\Hello\AppData\Local\Temp\ipykernel_14160\1971045298.py:4: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %%
class MyTable(Base):
    __tablename__ = 'medic_Data'
    
    channel_title = Column(String, primary_key=True)  # Changed from 'Channel Title'
    channel_username = Column(String)                 # Changed from 'Channel Username'
    id = Column(Integer)                              # It's best practice to use lowercase for variable names
    message = Column(String)
    date = Column(Date)
    media_path = Column(String)                       # Changed from 'Media Path'

# %%
Base.metadata.create_all(engine)

# %%
# Step 1: Read CSV file into a pandas DataFrame
csv_file = 'cleaned_data.csv'
df = pd.read_csv(csv_file)

# %%
df
# Out:
#       Unnamed: 0     Channel Title Channel Username  \
# 0              0            CheMed       @CheMed123
# 1              1            CheMed       @CheMed123
# 2              2            CheMed       @CheMed123
# 3              3            CheMed       @CheMed123
# 4              4            CheMed       @CheMed123
# ...          ...               ...              ...
# 2307        2999  የጤና ወግ - የጤና መረጃ       @yetenaweg
# 2308        3005  የጤና ወግ - የጤና መረጃ       @yetenaweg
# 2309        3009  የጤና ወግ - የጤና መረጃ       @yetenaweg
# 2310        3011  የጤና ወግ - የጤና መረጃ       @yetenaweg
# 2311        3014  የጤና ወግ - የጤና መረጃ       @yetenaweg
#
#                                  ID  \
# 0     1970-01-01 00:00:00.000000097
# 1     1970-01-01 00:00:00.000000096
# 2     1970-01-01 00:00:00.000000095
# 3     1970-01-01 00:00:00.000000094
# 4     1970-01-01 00:00:00.000000093
# ...                             ...
# 2307  1970-01-01 00:00:00.000001055
# 2308  1970-01-01 00:00:00.000001049
# ...

# %%
from datetime import datetime

# %%
# Parse the 'Date' column directly as datetime
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
df
# Out:
#       Unnamed: 0     Channel Title Channel Username  \
# 0              0            CheMed       @CheMed123
# 1              1            CheMed       @CheMed123
# 2              2            CheMed       @CheMed123
# 3              3            CheMed       @CheMed123
# 4              4            CheMed       @CheMed123
# ...          ...               ...              ...
# 2307        2999  የጤና ወግ - የጤና መረጃ       @yetenaweg
# 2308        3005  የጤና ወግ - የጤና መረጃ       @yetenaweg
# 2309        3009  የጤና ወግ - የጤና መረጃ       @yetenaweg
# 2310        3011  የጤና ወግ - የጤና መረጃ       @yetenaweg
# 2311        3014  የጤና ወግ - የጤና መረጃ       @yetenaweg
#
#                                  ID  \
# 0     1970-01-01 00:00:00.000000097
# 1     1970-01-01 00:00:00.000000096
# 2     1970-01-01 00:00:00.000000095
# 3     1970-01-01 00:00:00.000000094
# 4     1970-01-01 00:00:00.000000093
# ...                             ...
# 2307  1970-01-01 00:00:00.000001055
# 2308  1970-01-01 00:00:00.000001049
# ...

# %%
# Step 2: Insert data into the database
for index, row in df.iterrows():
    new_record = MyTable(
        channel_title=row['Channel Title'],
        channel_username=row['Channel Username'],
        id=row['ID'],
        message=row['Message'],
        date=row['Date'].date() if pd.notnull(row['Date']) else None,  # Convert date string to date object
        media_path=row['Media Path']
    )

    # Add the new record to the session
    session.add(new_record)

# %%
df
# Out:
#       Unnamed: 0     Channel Title Channel Username  \
# 0              0            CheMed       @CheMed123
# 1              1            CheMed       @CheMed123
# 2              2            CheMed       @CheMed123
# 3              3            CheMed       @CheMed123
# 4              4            CheMed       @CheMed123
# ...          ...               ...              ...
# 2307        2999  የጤና ወግ - የጤና መረጃ       @yetenaweg
# 2308        3005  የጤና ወግ - የጤና መረጃ       @yetenaweg
# 2309        3009  የጤና ወግ - የጤና መረጃ       @yetenaweg
# 2310        3011  የጤና ወግ - የጤና መረጃ       @yetenaweg
# 2311        3014  የጤና ወግ - የጤና መረጃ       @yetenaweg
#
#                                  ID  \
# 0     1970-01-01 00:00:00.000000097
# 1     1970-01-01 00:00:00.000000096
# 2     1970-01-01 00:00:00.000000095
# 3     1970-01-01 00:00:00.000000094
# 4     1970-01-01 00:00:00.000000093
# ...                             ...
# 2307  1970-01-01 00:00:00.000001055
# 2308  1970-01-01 00:00:00.000001049
# ...

# %%
{
    'id': int,  # Integer value
    'date': '2023-02-10 00:00:00'  # Timestamp or date field
}
# Out:
# {'id': int, 'date': '2023-02-10 00:00:00'}

# %%
# Establish a connection to the PostgreSQL database
conn = psycopg2.connect(
    host="localhost",
    dbname="medical_db",
    user="postgres",
    password="Akeab"
)

# Create a cursor object
cursor = conn.cursor()

# %%
print(df.keys())
# Out:
# Index(['Unnamed: 0', 'Channel Title', 'Channel Username', 'ID', 'Message',
#        'Date', 'Media Path'],
#       dtype='object')

# %% [markdown]
# # During my trial to Insert the data to PostgreSQL I was encounter an issue of InFailedSqlTransaction ERROR

# %%
insert_statement = """
    INSERT INTO Medical_Data (channel_title, channel_username, id, message, date, media_path)
    VALUES (%(channel_title)s, %(channel_username)s, %(id)s, %(message)s, %(date)s, %(media_path)s)
"""

# Ensure 'id' is an integer and 'date' is a valid date
conn.autocommit = False 
cursor.execute(insert_statement, df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Hello\Desktop\Html Tutorial\Document\KAIM Courses\Week-07_Data_Warehouse_Development\venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'channel_title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
conn.rollback()

# %%
# Commit the session to save changes
session.commit()

# Step 3: Query and print data
records = session.query(MyTable).all()
for record in records:
    print(record.channel_title, record.channel_username, record.message, record.date, record.media_path)

# Close the session
session.close()
# Out:
# ---------------------------------------------------------------------------
# InvalidTextRepresentation                 Traceback (most recent call last)
# File c:\Users\Hello\Desktop\Html Tutorial\Document\KAIM Courses\Week-07_Data_Warehouse_Development\venv\Lib\site-packages\sqlalchemy\engine\base.py:2118, in Connection._exec_insertmany_context(self, dialect, context)
#    2117     else:
# -> 2118         dialect.do_execute(
#    2119             cursor,
#    2120             sub_stmt,
#    2121             sub_params,
#    2122             context,
#    2123         )
#    2125 except BaseException as e:
#
# File c:\Users\Hello\Desktop\Html Tutorial\Document\KAIM Courses\Week-07_Data_Warehouse_Development\venv\Lib\site-packages\sqlalchemy\engine\default.py:941, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     940 def do_execute(self, cursor, statement, parameters, context=None):
# --> 941     cursor.execute(statement, parameters)
#
# ...
