# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
import logging

# %%
# Function to load and analyze data
def analyze_data(file_path):
    try:
        df = pd.read_csv(file_path)
        print(f"Data from {file_path}")
        print("\nHead of the DataFrame:")
        display(df.head())
        print("\nInfo of the DataFrame:")
        display(df.info())
        print("\nDescribe the DataFrame:")
        display(df.describe(include='all'))
    except Exception as e:
        print(f"Error processing file {file_path}: {e}")

# Analyze cheMed dataset
print("Analyzing cheMed dataset")
analyze_data('../Telegram_Scraper/cheMed123_data.csv') 
print("="*80)
# Out:
# Analyzing cheMed dataset
# Data from ../Telegram_Scraper/cheMed123_data.csv
#
# Head of the DataFrame:
#   Channel Title Channel Username  ID  \
# 0        CheMed       @CheMed123  97
# 1        CheMed       @CheMed123  96
# 2        CheMed       @CheMed123  95
# 3        CheMed       @CheMed123  94
# 4        CheMed       @CheMed123  93
#
#                                              Message  \
# 0  ⚠️Notice!\nDear esteemed customers,\nDue to fo...
# 1  Mela-One በውስጡ ሆርሞን ያለው ድንገተኛ ወሊድ መቆጣጠርያ ሲሆን ያለ...
# 2  አዚትሮማይሲን በሃኪም መድሃኒት ማዘዣ ከሚታዘዙ አንቲባዮቲኮች አንዱ ሲሆን...
# 3  Che-Med Trivia #3\n\nምግብና መጠጦች አንዳንድ መድሃኒቶች በደ...
# 4  Che-Med Trivia #2\n\nእንደ Ciprofloxacin, Doxycy...
#
#                         Date                Media Path
# 0  2023-02-10 12:23:06+00:00  photos\@CheMed123_97.jpg
# 1  2023-02-02 08:58:52+00:00  photos\@CheMed123_96.jpg
# 2  2023-02-01 08:59:37+00:00  photos\@CheMed123_95.jpg
# 3  2023-01-31 09:19:53+00:00  photos\@CheMed123_94.jpg
# 4  2023-01-30 09:45:25+00:00  photos\@CheMed123_93.jpg
# Info of the DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel Title     76 non-null     object
#  1   Channel Username  76 non-null     object
#  2   ID                76 non-null     int64
#  3   Message           63 non-null     object
#  4   Date              76 non-null     object
#  5   Media Path        72 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 3.7+ KB
# None
# Describe the DataFrame:
#        Channel Title Channel Username         ID  \
# count             76               76  76.000000
# unique             1                1        NaN
# top           CheMed       @CheMed123        NaN
# freq              76               76        NaN
# mean             NaN              NaN  49.710526
# std              NaN              NaN  29.149187
# min              NaN              NaN   1.000000
# 25%              NaN              NaN  24.500000
# 50%              NaN              NaN  49.500000
# 75%              NaN              NaN  76.250000
# max              NaN              NaN  97.000000
#
#                                                   Message  \
# count                                                  63
# unique                                                 59
# top     www.chemeds.org መድሀኒትዎን ለማግኘት ዘመናዊው መንገድ ነው፡፡ ...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                              Date                Media Path
# count                          76                        72
# unique                         76                        72
# top     2023-02-10 12:23:06+00:00  photos\@CheMed123_97.jpg
# freq                            1                         1
# mean                          NaN                       NaN
# std                           NaN                       NaN
# min                           NaN                       NaN
# 25%                           NaN                       NaN
# 50%                           NaN                       NaN
# 75%                           NaN                       NaN
# max                           NaN                       NaN
# ================================================================================

# %%
# Analyze Doctorset dataset
print("Analyzing Doctorset dataset")
analyze_data('../Telegram_Scraper/DoctorsET_data.csv')
print("="*80)
# Out:
# Analyzing Doctorset dataset
# Data from ../Telegram_Scraper/DoctorsET_data.csv
#
# Head of the DataFrame:
#       Channel Title Channel Username   ID  \
# 0  Doctors Ethiopia       @DoctorsET  864
# 1  Doctors Ethiopia       @DoctorsET  863
# 2  Doctors Ethiopia       @DoctorsET  862
# 3  Doctors Ethiopia       @DoctorsET  861
# 4  Doctors Ethiopia       @DoctorsET  860
#
#                                              Message  \
# 0  https://youtu.be/5DBoEm-8kmA?si=LDLuEecNfULJVD...
# 1  ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከ...
# 2  ሞት በስኳር \n\nለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን ይቀን...
# 3  ከ HIV የተፈወሰ ሰው አጋጥሟችሁ ያቃል ? ፈውስ እና ህክምና ?\n\nሙ...
# 4  በቅርብ ጊዜ በሃገራችን ላይ እየተስተዋለ ያለ የተመሳሳይ ፆታ ( Homos...
#
#                         Date                 Media Path
# 0  2023-12-18 17:04:02+00:00  photos\@DoctorsET_864.jpg
# 1  2023-11-03 16:14:39+00:00  photos\@DoctorsET_863.jpg
# 2  2023-10-02 16:37:39+00:00  photos\@DoctorsET_862.jpg
# 3  2023-09-16 07:54:32+00:00  photos\@DoctorsET_861.jpg
# 4  2023-09-01 16:16:15+00:00  photos\@DoctorsET_860.jpg
# Info of the DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 803 entries, 0 to 802
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel Title     803 non-null    object
#  1   Channel Username  803 non-null    object
#  2   ID                803 non-null    int64
#  3   Message           605 non-null    object
#  4   Date              803 non-null    object
#  5   Media Path        610 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 37.8+ KB
# None
# Describe the DataFrame:
#            Channel Title Channel Username          ID  \
# count                803              803  803.000000
# unique                 1                1         NaN
# top     Doctors Ethiopia       @DoctorsET         NaN
# freq                 803              803         NaN
# mean                 NaN              NaN  432.118306
# std                  NaN              NaN  245.731048
# min                  NaN              NaN    1.000000
# 25%                  NaN              NaN  219.500000
# 50%                  NaN              NaN  438.000000
# 75%                  NaN              NaN  642.500000
# max                  NaN              NaN  864.000000
#
#                               Message                       Date  \
# count                             605                        803
# unique                            591                        743
# top     #Dailytips \n#DOCTORSETHIOPIA  2022-02-04 18:22:07+00:00
# freq                                7                          9
# mean                              NaN                        NaN
# std                               NaN                        NaN
# min                               NaN                        NaN
# 25%                               NaN                        NaN
# 50%                               NaN                        NaN
# 75%                               NaN                        NaN
# max                               NaN                        NaN
#
#                        Media Path
# count                         610
# unique                        610
# top     photos\@DoctorsET_864.jpg
# freq                            1
# mean                          NaN
# std                           NaN
# min                           NaN
# 25%                           NaN
# 50%                           NaN
# 75%                           NaN
# max                           NaN
# ================================================================================

# %%
# Analyze EAHCI dataset
print("Analyzing EAHCI dataset")
analyze_data('../Telegram_Scraper/EAHCI_data.csv')
print("="*80)
# Out:
# Analyzing EAHCI dataset
# Data from ../Telegram_Scraper/EAHCI_data.csv
#
# Head of the DataFrame:
#                                        Channel Title Channel Username    ID  \
# 0  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2399
# 1  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2397
# 2  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2396
# 3  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2395
# 4  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2394
#
#                                              Message  \
# 0  💥 እሁድ ይጀምራል እንዳያመልጥዎ 💥\n#Obstetric_Ultrasound_...
# 1                                                NaN
# 2  💥ዛሬ ይጀምራል\n#የሞያ ፈቃድ በቅርቡ ለምታሳድሱ  💥            ...
# 3  💥\n#የሞያ ፈቃድ በቅርቡ ለምታሳድሱ  💥             \n\n#CP...
# 4                                                NaN
#
#                         Date              Media Path
# 0  2024-10-11 15:32:14+00:00  photos\@EAHCI_2399.jpg
# 1  2024-10-11 14:57:29+00:00                     NaN
# 2  2024-10-10 13:40:09+00:00  photos\@EAHCI_2396.jpg
# 3  2024-10-09 10:46:24+00:00  photos\@EAHCI_2395.jpg
# 4  2024-10-07 10:56:58+00:00                     NaN
# Info of the DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel Title     1000 non-null   object
#  1   Channel Username  1000 non-null   object
#  2   ID                1000 non-null   int64
#  3   Message           796 non-null    object
#  4   Date              1000 non-null   object
#  5   Media Path        870 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB
# None
# Describe the DataFrame:
#                                             Channel Title Channel Username  \
# count                                                1000             1000
# unique                                                  1                1
# top     ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI
# freq                                                 1000             1000
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
#
#                  ID                                            Message  \
# count   1000.000000                                                796
# unique          NaN                                                660
# top             NaN  #CPD_በተመጣጣኝ_ክፍያ\n#Title_Syndromic Management (...
# freq            NaN                                                  3
# mean    1830.715000                                                NaN
# std      325.835978                                                NaN
# min     1222.000000                                                NaN
# 25%     1558.750000                                                NaN
# 50%     1833.500000                                                NaN
# 75%     2105.250000                                                NaN
# max     2399.000000                                                NaN
#
#                              Date              Media Path
# count                        1000                     870
# unique                        915                     870
# top     2024-06-26 17:19:24+00:00  photos\@EAHCI_2399.jpg
# freq                            5                       1
# mean                          NaN                     NaN
# std                           NaN                     NaN
# min                           NaN                     NaN
# 25%                           NaN                     NaN
# 50%                           NaN                     NaN
# 75%                           NaN                     NaN
# max                           NaN                     NaN
# ================================================================================

# %%
# Analyze lobelia4cosmetics dataset
print("Analyzing lobelia4cosmetics dataset")
analyze_data('../Telegram_Scraper/lobelia4cosmetics_data.csv')
print("="*80)
# Out:
# Analyzing lobelia4cosmetics dataset
# Data from ../Telegram_Scraper/lobelia4cosmetics_data.csv
#
# Head of the DataFrame:
#                     Channel Title    Channel Username     ID  \
# 0  Lobelia pharmacy and cosmetics  @lobelia4cosmetics  12411
# 1  Lobelia pharmacy and cosmetics  @lobelia4cosmetics  12410
# 2  Lobelia pharmacy and cosmetics  @lobelia4cosmetics  12409
# 3  Lobelia pharmacy and cosmetics  @lobelia4cosmetics  12408
# 4  Lobelia pharmacy and cosmetics  @lobelia4cosmetics  12407
#
#                                              Message  \
# 0  EUCERIN PIGMENT CONTROL \nPrice 4500 birr \nTe...
# 1  EUCERIN OIL CONTROL \nPrice 4500 birr \nTelegr...
# 2  NEUTROGENA RAPID TONE REPAIR \nPrice 3000 birr...
# 3  NEUTROGENA INVISIBLE DAILY  DEFENSE \nPrice 35...
# 4  NEUTROGENA RETINOL SPF 30\nPrice 4500 birr \nT...
#
#                         Date                           Media Path
# 0  2024-10-10 14:47:05+00:00  photos\@lobelia4cosmetics_12411.jpg
# 1  2024-10-10 14:47:05+00:00  photos\@lobelia4cosmetics_12410.jpg
# 2  2024-10-10 14:47:05+00:00  photos\@lobelia4cosmetics_12409.jpg
# 3  2024-10-10 14:47:05+00:00  photos\@lobelia4cosmetics_12408.jpg
# 4  2024-10-10 14:47:05+00:00  photos\@lobelia4cosmetics_12407.jpg
# Info of the DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel Title     1000 non-null   object
#  1   Channel Username  1000 non-null   object
#  2   ID                1000 non-null   int64
#  3   Message           970 non-null    object
#  4   Date              1000 non-null   object
#  5   Media Path        1000 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB
# None
# Describe the DataFrame:
#                          Channel Title    Channel Username            ID  \
# count                             1000                1000   1000.000000
# unique                               1                   1           NaN
# top     Lobelia pharmacy and cosmetics  @lobelia4cosmetics           NaN
# freq                              1000                1000           NaN
# mean                               NaN                 NaN  11895.805000
# std                                NaN                 NaN    296.637541
# min                                NaN                 NaN  11386.000000
# 25%                                NaN                 NaN  11639.750000
# 50%                                NaN                 NaN  11890.500000
# 75%                                NaN                 NaN  12153.250000
# max                                NaN                 NaN  12411.000000
#
#                                                   Message  \
# count                                                 970
# unique                                                167
# top     NIDO USA 2.2KG\nPrice 5900 birr \nTelegram htt...
# freq                                                   37
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                              Date                           Media Path
# count                        1000                                 1000
# unique                        199                                 1000
# top     2024-10-08 04:35:59+00:00  photos\@lobelia4cosmetics_12411.jpg
# freq                           25                                    1
# mean                          NaN                                  NaN
# std                           NaN                                  NaN
# min                           NaN                                  NaN
# 25%                           NaN                                  NaN
# 50%                           NaN                                  NaN
# 75%                           NaN                                  NaN
# max                           NaN                                  NaN
# ================================================================================

# %%
# Analyze yetenaweg dataset
print("Analyzing yetenaweg dataset")
analyze_data('../Telegram_Scraper/yetenaweg_data.csv')
print("="*80)
# Out:
# Analyzing yetenaweg dataset
# Data from ../Telegram_Scraper/yetenaweg_data.csv
#
# Head of the DataFrame:
#       Channel Title Channel Username    ID   Message  \
# 0  የጤና ወግ - የጤና መረጃ       @yetenaweg  1181       NaN
# 1  የጤና ወግ - የጤና መረጃ       @yetenaweg  1180  ተጀምሯል !!
# 2  የጤና ወግ - የጤና መረጃ       @yetenaweg  1179       NaN
# 3  የጤና ወግ - የጤና መረጃ       @yetenaweg  1178       NaN
# 4  የጤና ወግ - የጤና መረጃ       @yetenaweg  1177       NaN
#
#                         Date                  Media Path
# 0  2024-10-06 16:26:40+00:00                         NaN
# 1  2024-10-06 15:03:40+00:00                         NaN
# 2  2024-10-06 14:58:28+00:00                         NaN
# 3  2024-10-04 13:14:17+00:00  photos\@yetenaweg_1178.jpg
# 4  2024-10-04 13:14:17+00:00  photos\@yetenaweg_1177.jpg
# Info of the DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel Title     136 non-null    object
#  1   Channel Username  136 non-null    object
#  2   ID                136 non-null    int64
#  3   Message           53 non-null     object
#  4   Date              136 non-null    object
#  5   Media Path        101 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 6.5+ KB
# None
# Describe the DataFrame:
#            Channel Title Channel Username           ID   Message  \
# count                136              136   136.000000        53
# unique                 1                1          NaN        48
# top     የጤና ወግ - የጤና መረጃ       @yetenaweg          NaN  ተጀምሯል !!
# freq                 136              136          NaN         6
# mean                 NaN              NaN  1108.838235       NaN
# std                  NaN              NaN    41.762684       NaN
# min                  NaN              NaN  1032.000000       NaN
# 25%                  NaN              NaN  1073.750000       NaN
# 50%                  NaN              NaN  1108.500000       NaN
# 75%                  NaN              NaN  1145.250000       NaN
# max                  NaN              NaN  1181.000000       NaN
#
#                              Date                  Media Path
# count                         136                         101
# unique                        109                         101
# top     2024-08-19 16:25:15+00:00  photos\@yetenaweg_1178.jpg
# freq                            2                           1
# mean                          NaN                         NaN
# std                           NaN                         NaN
# min                           NaN                         NaN
# 25%                           NaN                         NaN
# 50%                           NaN                         NaN
# 75%                           NaN                         NaN
# max                           NaN                         NaN
# ================================================================================

# %%
# Analyze imageoflobeli dataset
print("Analyzing imageoflobeli dataset")
analyze_data('imageoflobeli.csv')
print("="*80)
# Out:
# Analyzing imageoflobeli dataset
# Data from imageoflobeli.csv
#
# Head of the DataFrame:
#    1.840000000000000000e+02  1.830000000000000000e+02  \
# 0                     118.0                     118.0
# 1                     255.0                     255.0
# 2                      55.0                      55.0
# 3                     118.0                     118.0
# 4                      44.0                      44.0
#
#    1.780000000000000000e+02  1.760000000000000000e+02  \
# 0                     118.0                     118.0
# 1                     255.0                     255.0
# 2                      56.0                      56.0
# 3                     118.0                     118.0
# 4                      44.0                      44.0
#
#    1.720000000000000000e+02  1.790000000000000000e+02  \
# 0                     118.0                     118.0
# 1                     255.0                     255.0
# 2                      55.0                      55.0
# 3                     118.0                     118.0
# 4                      44.0                      44.0
#
#    1.800000000000000000e+02  1.710000000000000000e+02  \
# 0                     118.0                     118.0
# 1                     255.0                     255.0
# 2                      55.0                      55.0
# 3                     118.0                     118.0
# 4                      44.0                      44.0
#
#    1.680000000000000000e+02  1.660000000000000000e+02  ...  \
# 0                     118.0                     118.0  ...
# 1                     255.0                     255.0  ...
# 2                      55.0                      55.0  ...
# 3                     118.0                     118.0  ...
# 4                      44.0                      44.0  ...
#
#    5.300000000000000000e+01.84  5.700000000000000000e+01.179  \
# 0                        118.0                         118.0
# 1                         36.0                          36.0
# 2                        219.0                         219.0
# 3                        118.0                         118.0
# 4                        255.0                         255.0
#
#    5.500000000000000000e+01.218  5.300000000000000000e+01.85  \
# 0                         118.0                        118.0
# 1                          36.0                         36.0
# 2                         219.0                        219.0
# 3                         118.0                        118.0
# 4                         255.0                        255.0
#
#    5.600000000000000000e+01.394  5.500000000000000000e+01.219  \
# 0                         118.0                         118.0
# 1                          36.0                          36.0
# 2                         219.0                         219.0
# 3                         118.0                         118.0
# 4                         255.0                         255.0
#
#    5.300000000000000000e+01.86  5.600000000000000000e+01.395  \
# 0                        118.0                         118.0
# 1                         36.0                          36.0
# 2                        219.0                         219.0
# 3                        118.0                         118.0
# 4                        255.0                         255.0
#
#    5.200000000000000000e+01.74  5.400000000000000000e+01.144
# 0                        118.0                         118.0
# 1                         36.0                          36.0
# 2                        219.0                         214.0
# 3                        118.0                         118.0
# 4                        255.0                         255.0
#
# [5 rows x 10000 columns]
# Info of the DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Columns: 10000 entries, 1.840000000000000000e+02 to 5.400000000000000000e+01.144
# dtypes: float64(10000)
# memory usage: 196.8 MB
# None
# Describe the DataFrame:
#        1.840000000000000000e+02  1.830000000000000000e+02  \
# count               2580.000000               2580.000000
# mean                 188.618605                188.176357
# std                   87.667908                 87.531386
# min                    0.000000                  0.000000
# 25%                  143.000000                135.750000
# 50%                  236.000000                237.000000
# 75%                  255.000000                255.000000
# max                  255.000000                255.000000
#
#        1.780000000000000000e+02  1.760000000000000000e+02  \
# count               2580.000000               2580.000000
# mean                 187.840698                187.464729
# std                   87.059422                 87.403087
# min                    0.000000                  0.000000
# 25%                  136.000000                133.500000
# 50%                  233.000000                232.000000
# 75%                  255.000000                255.000000
# max                  255.000000                255.000000
#
#        1.720000000000000000e+02  1.790000000000000000e+02  \
# count               2580.000000               2580.000000
# mean                 187.572868                187.424031
# std                   87.068725                 86.728222
# min                    0.000000                  0.000000
# 25%                  131.750000                131.000000
# 50%                  233.000000                232.000000
# 75%                  255.000000                255.000000
# max                  255.000000                255.000000
#
#        1.800000000000000000e+02  1.710000000000000000e+02  \
# count               2580.000000               2580.000000
# mean                 187.319767                187.661628
# std                   86.824665                 86.827876
# min                    0.000000                  0.000000
# 25%                  132.000000                128.000000
# 50%                  233.000000                234.000000
# 75%                  255.000000                255.000000
# max                  255.000000                255.000000
#
#        1.680000000000000000e+02  1.660000000000000000e+02  ...  \
# count               2580.000000               2580.000000  ...
# mean                 185.570155                186.191085  ...
# std                   87.660317                 87.045644  ...
# min                    0.000000                  0.000000  ...
# 25%                  115.750000                114.000000  ...
# 50%                  233.000000                234.000000  ...
# 75%                  255.000000                255.000000  ...
# max                  255.000000                255.000000  ...
#
#        5.300000000000000000e+01.84  5.700000000000000000e+01.179  \
# count                  2580.000000                   2580.000000
# mean                    178.790698                    177.425581
# std                      87.752607                     89.049408
# min                       0.000000                      0.000000
# 25%                     102.000000                    102.000000
# 50%                     221.500000                    224.000000
# 75%                     255.000000                    255.000000
# max                     255.000000                    255.000000
#
#        5.500000000000000000e+01.218  5.300000000000000000e+01.85  \
# count                   2580.000000                  2580.000000
# mean                     177.668605                   177.399612
# std                       89.185435                    89.348005
# min                        0.000000                     0.000000
# 25%                      102.000000                    95.000000
# 50%                      225.000000                   225.000000
# 75%                      255.000000                   255.000000
# max                      255.000000                   255.000000
#
#        5.600000000000000000e+01.394  5.500000000000000000e+01.219  \
# count                   2580.000000                   2580.000000
# mean                     179.022481                    178.155814
# std                       88.461111                     89.747799
# min                        0.000000                      0.000000
# 25%                      103.750000                    103.000000
# 50%                      224.000000                    225.000000
# 75%                      255.000000                    255.000000
# max                      255.000000                    255.000000
#
#        5.300000000000000000e+01.86  5.600000000000000000e+01.395  \
# count                  2580.000000                   2580.000000
# mean                    177.273256                    177.660465
# std                      89.622149                     89.493561
# min                       0.000000                      0.000000
# 25%                     100.000000                    102.000000
# 50%                     225.000000                    224.000000
# 75%                     255.000000                    255.000000
# max                     255.000000                    255.000000
#
#        5.200000000000000000e+01.74  5.400000000000000000e+01.144
# count                  2580.000000                   2580.000000
# mean                    175.889147                    175.737597
# std                      90.565721                     90.538793
# min                       0.000000                      0.000000
# 25%                     100.000000                     98.000000
# 50%                     224.000000                    224.000000
# 75%                     255.000000                    255.000000
# max                     255.000000                    255.000000
#
# [8 rows x 10000 columns]
# ================================================================================
